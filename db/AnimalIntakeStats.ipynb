# %%
import csv

def most_common(L):
    if len(L) > 0:
        return max(set(L), key=L.count)
    else: 
        return 0

# information on the animal services intake for Los Angeles
f = open('Animal_Services_Intake_Data.csv')
csv_f = csv.reader(f)

numCats = 0
numDogs = 0
numHorses = 0
numOther = 0
numTotalPets = sum(1 for row in csv_f) - 1
catBreeds = []
catWhere = []

f.seek(0)

for row in csv_f:
    #print row[5]
    if row[5] == 'CAT':
        numCats += 1
        catBreeds.append(row[7])
        catWhere.append(row[0])
    elif row[5] == 'DOG':
        numDogs += 1
    elif row[5] == 'EQUINE':
        numHorses += 1
    else:
        numOther += 1

outputFile = open("AnimalIntakeStats.txt", "w")
outputFile.write("numTotalPets = " + str(numTotalPets) + ';\n')
outputFile.write("numCats = " + str(numCats) + ";\n")
outputFile.write("numDogs = " + str(numDogs) + ";\n")
outputFile.write("numHorses = " + str(numHorses) + ";\n")
outputFile.write("numOther = " + str(numOther) + ";\n")
outputFile.write('catBreeds = ["' + '","'.join(catBreeds) + '"];\n')
outputFile.write('catWhere = ["'+ '","'.join(catWhere) + '"];\n')

f.close()
outputFile.close()
    
print 'Number of total pets: '
print numTotalPets
print 'Number of cats surrendered: '
print numCats
print 'Most common cat breed surrendered: '
print most_common(catBreeds)
print 'Most common location in LA of cat breed surrendered: '
print most_common(catWhere)
print 'Breeds of cats surrendered: '
print catBreeds
print 'Locations of cats surrendered: '
print catWhere
# Out:
# Number of total pets:
# 187593
# Number of cats surrendered:
# 63853
# Most common cat breed surrendered:
# DOMESTIC SH
# Most common location in LA of cat breed surrendered:
# E VALLEY
# Breeds of cats surrendered:
# ['DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'HIMALAYAN', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'SIAMESE', 'SNOWSHOE', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'AMER SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC SH', 'DOMESTIC SH', 'AMER SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'AMER SH', 'MAINE COON', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'MANX', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'AMER SH', 'SNOWSHOE', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'BOMBAY', 'BOMBAY', 'PERSIAN', 'MAINE COON', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC SH', 'NORWGN FOREST', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'MAINE COON', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'AMER SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'HIMALAYAN', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'DOMESTIC LH', 'AMER SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC LH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'DOMESTIC SH', 'SIAMESE', 'SIAMESE', 'SIAMESE', 'DOMESTIC SH', 'AMER SH', 'DOME ...
# Locations of cats surrendered:
# ['N CENTRA', 'E VALLEY', 'W VALLEY', 'E VALLEY', 'W VALLEY', 'W VALLEY', 'W VALLEY', 'W VALLEY', 'W LA', 'W VALLEY', 'HARBOR', 'E VALLEY', 'E VALLEY', 'E VALLEY', 'S LA', 'W VALLEY', 'W VALLEY', 'N CENTRA', 'W LA', 'E VALLEY', 'E VALLEY', 'HARBOR', 'HARBOR', 'N CENTRA